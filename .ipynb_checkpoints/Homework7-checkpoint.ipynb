# %% [markdown]
# # Homework 7
# <h3>Advanced Algorithmics</h3>

# %% [markdown]
# <h3>Student Info</h3>
# Başar Turgut<br>
# B79636

# %% [markdown]
# ## Ex 1

# %% [markdown]
# <b>Question</b> : Now that you have completed the submission of your essay about a published article, it is time to reflect upon that. We will soon be asking for peer-review by co-students. But before that, please fill in the self-assessment form here. As an author you do not need to give feedback to yourself; although you may also consider it. E.g. what weaknesses you observed in your writing and what would you like to fix before the final version.
#
# <b>Answer </b>:
#
# I have reviewed my mistakes, original paper and works need to be done before final version.

# %% [markdown]
# ## Ex 2

# %% [markdown]
# <b>Question</b> : During the discussion on hashing we did not ask, how to deal when hash table grows full and/or we do not know in advance the final nr. of elements to be hashed. One answer to this is so called "Extendible hashing" or also "Dynamic hashing". Please study online materials, e.g https://loonytek.com/2016/05/17/extendible-hashing/ for 30-40 minutes on this topic. In submission highlight most useful resource(s). To validate that you did EX2, you must also do EX3.
#
# <b>Answer </b>:
#
# I have worked at least 45 mins for the given blog post. I could not understand the "In submission highlight most useful resource(s)" sentence. I assumed that asked to highlight some key concepts and explaining how this method works. Because of that, i tried to write simple bulletted highlightpoints, a scheme based explanation to the question 3.

# %% [markdown]
# ## Ex 3

# %% [markdown]
# <b>Question</b> : Now summarise the key points of extendible hashing, providing also one illustration (can be from the net; properly cited of course). Approximately 0.5-1 pages should do. Provide key ideas as bullet points, for example.
#
# <b>Answer </b>:
#
# <li>Basically, extendible hashing and linear hashing both are dynamic hashing techniques.</li>
# <li>Linear hashing we have overflow buckets but in extendible hashing we do not allow any overflow. If any situation occurs, we split bucket immediately.</li>
# <li>Extendible hashing mapping of global directory(depth) can map many to one or one to one. If buckets(local) are full it will be splitted and mostly splits leads to one to one relations.</li>
# <li>If we have any local bucket full, we need to increment its local lsb j one bit to split bucket. If global lsb is already splitted we just split many to one relation(2-1 or 4-1 etc) to smaller many to one or one to one(4to1 can be splitted to 2to1 or 2to1 can be splitted to 1to1).</li>
#
# <img src="img.png">
#
# We will explain a step to show how to handle a complex step. If we add 15, 15 will be hashed to B3 but it is full. When we increment j with 1 and split buckets, it will not be enough because every number at bucket b3(from scheme) has remaining 7 when divided 8. 15 has the remaining 7 when divided 8 too. In this case, we need to increment global lsb i to 4. So, we will finally will have enough space to store.

# %% [markdown]
# ## Ex 4

# %% [markdown]
# <b>Question</b> : There are many data types that can be represented as graphs. Study online collection at https://snap.stanford.edu/data/. Select from there 4 different types and sizes of graphs. First, consider them as undirected and characterise them by calculating:
#
# Nr of nodes
# Nr of edges
# Distribution of node degrees
#
# <b>Answer </b>:

# %%
import snap
import matplotlib.pyplot as plt

gh = snap.LoadEdgeList(snap.PUNGraph, "facebook/0.edges", 0, 1)
DegToCntV1 = snap.TIntPrV()
snap.GetDegCnt(gh, DegToCntV1)
print("Number of nodes::" + str(snap.CntNonZNodes(gh)))
print("Number of edges::" + str(snap.CntUniqUndirEdges(gh)))
facebook_hist={}
for item in DegToCntV1:
    facebook_hist[item.GetVal2()] = item.GetVal1()
plt.bar(facebook_hist.keys(), facebook_hist.values(), color='g')
fig_size = [14, 7]
plt.rcParams["figure.figsize"] = fig_size
plt.show()

gh2 = snap.LoadEdgeList(snap.PUNGraph, "facebook/348.edges", 0, 1)
DegToCntV2 = snap.TIntPrV()
snap.GetDegCnt(gh2, DegToCntV2)
print("Number of nodes::" + str(snap.CntNonZNodes(gh2)))
print("Number of edges::" + str(snap.CntUniqUndirEdges(gh2)))
f2_hist={}
for item in DegToCntV2:
    f2_hist[item.GetVal2()] = item.GetVal1()
    
plt.bar(map(str, f2_hist.keys()), f2_hist.values(), color='y')
plt.xticks(rotation=90)
plt.show()

gh3 = snap.LoadEdgeList(snap.PUNGraph, "facebook/107.edges", 0, 1)
DegToCntV3 = snap.TIntPrV()
snap.GetDegCnt(gh3, DegToCntV3)
print("Number of nodes::" + str(snap.CntNonZNodes(gh3)))
print("Number of edges::" + str(snap.CntUniqUndirEdges(gh3)))
f3_hist={}
for item in DegToCntV3:
    f3_hist[item.GetVal2()] = item.GetVal1()
plt.bar(map(str, f3_hist.keys()), f3_hist.values(), color='r')
plt.xticks(rotation=90)
plt.show()

gh4 = snap.LoadEdgeList(snap.PUNGraph, "facebook/686.edges", 0, 1)
DegToCntV4 = snap.TIntPrV()
snap.GetDegCnt(gh4, DegToCntV4)
print("Number of nodes::" + str(snap.CntNonZNodes(gh4)))
print("Number of edges::" + str(snap.CntUniqUndirEdges(gh4)))
f4_hist={}
for item in DegToCntV4:
    f4_hist[item.GetVal2()] = item.GetVal1()
plt.bar(map(str, f4_hist.keys()), f4_hist.values(), color='b')
plt.xticks(rotation=90)
plt.show()
# Out:
# Number of nodes::333
# Number of edges::2519
# Number of nodes::224
# Number of edges::3192
# Number of nodes::1034
# Number of edges::26749
# Number of nodes::168
# Number of edges::1656

# %% [markdown]
# ## Ex 5

# %% [markdown]
# <b>Question</b> : Implement an BFS algorithm for the very same graphs (considering graphs unweighted, undirected).
#
# Measure or estimate time for 1000 BFS searches from random start vertices; reporting also the "depth of the component" starting from different vertices.
# Estimate the diameter of the graphs (based on 1000 searches, or more or less, if needed for computational time).
#
# <b>Answer </b>:

# %%
import time

def bfs(graph, start):
    special = 666
    visited, queue = set(), [start, special]
    depth = 0
    while len(queue) > 1:
        vertex = queue.pop(0)
        if vertex == special:
            depth = depth + 1;
            queue.append(special);
        elif vertex not in visited:
            visited.add(vertex)
            queue.extend(set([Id for Id in graph.GetNI(vertex).GetOutEdges()]) - visited)
    #print depth
    return depth

graphs = [gh, gh2, gh3, gh4]
for g in graphs:
    Rnd = snap.TRnd(53)#seed
    deptharray = []
    starttime = time.time()
    for i in range(0, 1000):
        Rnd.Randomize()
        start = g.GetRndNId(Rnd)
        depth = bfs(g, start)
        deptharray.append(depth)
    t = time.time() - starttime
    diameter = max(deptharray)
    print("Running Time::" + str(t) + "sec, Dia::" + str(diameter))
# Out:
# Running Time::4.20799994469sec, Dia::11
# Running Time::5.4319999218sec, Dia::9
# Running Time::148.871000051sec, Dia::9
# Running Time::2.85299992561sec, Dia::7

# %% [markdown]
# ## Ex 6

# %% [markdown]
# <b>Question</b> : When doing the BFS in Task 5, test also for the bipartiteness of the graph. Most of them aren't clearly. Find at least one that is. For those that are not bipartite - report how quickly do you detect that based on BFS, e.g. for X2 searches it was already when going to "2 hop" neighbourhood when you discovered it; for X3 searches within 3 hops, etc...
#
# <b>Answer </b>:

# %%
def coloring(graph, start):
    special = 666
    visited, queue = set(), [start, special]
    depth = 0
    black, red = set(), set()
    isBlack = True
    while len(queue) > 1:
        vertex = queue.pop(0)
        if vertex == special:
            depth = depth + 1;
            queue.append(special);
            isBlack = not isBlack;
        elif vertex not in visited:
            visited.add(vertex)
            if isBlack == True:
                black.add(vertex)
            else:
                red.add(vertex)
            queue.extend(set([Id for Id in graph.GetNI(vertex).GetOutEdges()]) - visited)
    return black, red

graphs = [gh, gh2, gh3, gh4]
for g in graphs:
    Rnd = snap.TRnd(53)#seed
    Rnd.Randomize()
    start = g.GetRndNId(Rnd)
    black, red = coloring(g, start)
    for edge in g.Edges():
        src = edge.GetSrcNId()
        dst = edge.GetDstNId()
        if (src in black and dst in black) or (src in red and dst in red):
            print("Biparitite Detected::Src" + str(src) + ",dst::" + str(dst))
            break
# Out:
# Biparitite Detected::Src236,dst::248
# Biparitite Detected::Src436,dst::438
# Biparitite Detected::Src953,dst::978
# Biparitite Detected::Src827,dst::830

# %% [markdown]
# We did not check hoop detected because we did not implemented to construct tree and after we color every node, it is not easy to find depth of particular node without tree.

# %% [markdown]
# # Ex 7

# %% [markdown]
# <b>Question</b> : In above task, take the freedom to remove greedily those edges that make graphs non-bipartite. There may be different ways foir that - to remove the edge when you first detected a problem; or remove previous that caused the "problem" to be made now. Characterise the same graphs before and after using the same simple measures as the degree distribution and the diameter (before and after).
#
# <b>Answer </b>:

# %%
graphs = [gh, gh2, gh3, gh4]
for g in graphs:
    deptharray = []
    for i in range(0, 1000):
        Rnd.Randomize()
        start = g.GetRndNId(Rnd)
        depth = bfs(g, start)
        deptharray.append(depth)
    diameter = max(deptharray)
    print("Dia::" + str(diameter))
    DegToCnt = snap.TIntPrV()
    snap.GetDegCnt(g, DegToCnt)
    print("Number of nodes::" + str(snap.CntNonZNodes(g)))
    print("Number of edges::" + str(snap.CntUniqUndirEdges(g)))
    hist={}
    for item in DegToCnt:
        hist[item.GetVal2()] = item.GetVal1()
    plt.bar(hist.keys(), hist.values(), color='r')
    fig_size = [14, 7]
    plt.rcParams["figure.figsize"] = fig_size
    plt.show()
    
    Rnd = snap.TRnd(53)#seed
    Rnd.Randomize()
    start = g.GetRndNId(Rnd)
    black, red = coloring(g, start)
    
    dell = snap.TIntV()
    delList = []
    for edge in g.Edges() :
        src = edge.GetSrcNId()
        dst = edge.GetDstNId()
        if (src in black and dst in black) or (src in red and dst in red):
            if not src in delList:
                delList.append(src)
                dell.Add(src)
          
    snap.DelNodes(g, dell)
            
    deptharray = []
    for i in range(0, 1000):
        Rnd.Randomize()
        start = g.GetRndNId(Rnd)
        depth = bfs(g, start)
        deptharray.append(depth)
    diameter = max(deptharray)
    print("Dia::" + str(diameter))
    
    snap.GetDegCnt(g, DegToCnt)
    print("Number of nodes::" + str(snap.CntNonZNodes(g)))
    print("Number of edges::" + str(snap.CntUniqUndirEdges(g)))
    hist={}
    for item in DegToCnt:
        hist[item.GetVal2()] = item.GetVal1()
    plt.bar(hist.keys(), hist.values(), color='g')
    fig_size = [14, 7]
    plt.rcParams["figure.figsize"] = fig_size
    plt.show()
# Out:
# Number of nodes::333
# Number of edges::2519
# Dia::8
# Number of nodes::76
# Number of edges::61
# Number of nodes::224
# Number of edges::3192
# Dia::4
# Number of nodes::19
# Number of edges::12
# Number of nodes::1034
# Number of edges::26749
# Dia::6
# Number of nodes::64
# Number of edges::48
# Number of nodes::168
# Number of edges::1656
# Dia::8
# Number of nodes::31
# Number of edges::27

# %% [markdown]
# # References

# %% [markdown]
# [1] http://eddmann.com/posts/depth-first-search-and-breadth-first-search-in-python/<br>
# [2] https://stackoverflow.com/questions/31247634/how-to-keep-track-of-depth-in-breadth-first-search<br>
# [3] https://loonytek.com/2016/05/17/extendible-hashing/<br>
